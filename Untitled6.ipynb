# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
x = []
y = []
for i in range(1000):
    x.append(list(map(float, "{:010b}".format(i))))
    y.append(list(map(float, "{:010b}".format((i + 1)))))
x,y = np.array(x), np.array(y)

# %%
x.shape
# Out:
# (1000, 10)

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(10,)))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(32, activation='hard_sigmoid', input_shape=(32,)))
model.add(Dense(10, activation='sigmoid'))

model.compile(optimizer='rmsprop',loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 32)                352
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# ...
# Total params: 2,794
# Trainable params: 2,794
# Non-trainable params: 0
# _________________________________________________________________

# %%
data = model.fit(x = x, y = y, batch_size=100, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 1000/1000 [==============================] - 0s - loss: 3.9762e-04 - acc: 0.9999
# Epoch 2/200
# 1000/1000 [==============================] - 0s - loss: 3.9972e-04 - acc: 0.9999
# Epoch 3/200
# 1000/1000 [==============================] - 0s - loss: 4.0254e-04 - acc: 0.9998
# Epoch 4/200
# 1000/1000 [==============================] - 0s - loss: 3.9121e-04 - acc: 0.9998
# Epoch 5/200
# 1000/1000 [==============================] - 0s - loss: 4.0680e-04 - acc: 0.9998
# Epoch 6/200
# 1000/1000 [==============================] - 0s - loss: 3.9144e-04 - acc: 0.9998
# Epoch 7/200
# 1000/1000 [==============================] - 0s - loss: 3.8871e-04 - acc: 0.9999
# Epoch 8/200
# 1000/1000 [==============================] - 0s - loss: 3.9189e-04 - acc: 0.9999
# Epoch 9/200
# 1000/1000 [==============================] - 0s - loss: 3.9067e-04 - acc: 0.9998
# Epoch 10/200
# 1000/1000 [==============================] - 0s - loss: 3.8237e-04 - acc: 0.9999
# Epoch 11/200
# ...

# %%
model.get_weights()
# Out:
# [array([[ 0.03625397, -0.05183161, -0.16716647, -0.62370747,  0.15737206,
#           0.14974445,  0.09570822, -0.65138185,  1.4972533 ,  1.05226636,
#          -0.235045  , -0.27402517,  1.07037413,  0.21307333, -0.19652602,
#           0.05357918,  0.87385684,  0.28612462,  0.72055221,  1.07788372,
#          -0.37593266,  0.11349887, -0.09645551, -0.12436196, -0.0163298 ,
#          -0.45446363,  0.96377885,  0.48823303, -0.07637256, -0.24219938,
#          -0.00551545,  0.4049885 ],
#         [ 0.8168999 ,  0.034915  , -0.77674073,  0.0297642 ,  0.51899928,
#           0.61039567,  0.51935965, -0.02204793,  0.90505379, -0.35113111,
#          -0.11782192, -0.50544047, -0.10575073, -0.02082179,  0.38352418,
#          -0.35657293,  1.18072987,  1.04688537, -0.45436499, -0.04857145,
#           1.4408294 , -0.27612102,  0.24711874,  0.30673897,  0.17201927,
#          -0.53303432,  1.10226882,  0.4581188 ,  1.00958359, -0.56799632,
#           0.21252206,  0.73812336],
# ...

# %%
No, Yes = model.evaluate(np.array([list(map(float, "{:010b}".format(23)))]),
                         np.array([list(map(float, "{:010b}".format(24)))]), batch_size=128)
if Yes > No:
    print('Yes')
else:
    print('NO')
No, Yes
# Out:
# 1/1 [==============================] - 0s
# Yes
# (8.2534701505210251e-05, 1.0)
