# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.activations import 
import numpy as np

# %%
x = []
y = []
for i in range(1000):
    x.append(list(map(float, "{:010b}".format(i))))
    y.append(list(map(float, "{:010b}".format((i + 1)))))
x,y = np.array(x), np.array(y)

# %%
x.shape
# Out:
# (10, 4)

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(10,)))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(32, activation='hard_sigmoid', input_shape=(32,)))
model.add(Dense(10, activation='sigmoid'))

model.compile(optimizer='rmsprop',loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_33 (Dense)             (None, 32)                352
# _________________________________________________________________
# dense_34 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_35 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                330
# ...
# Total params: 2,794
# Trainable params: 2,794
# Non-trainable params: 0
# _________________________________________________________________

# %%
data = model.fit(x = x, y = y, batch_size=100, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 0s - loss: 6.9193e-06 - acc: 1.0000
# Epoch 2/100
# 1000/1000 [==============================] - 0s - loss: 4.4598e-06 - acc: 1.0000
# Epoch 3/100
# 1000/1000 [==============================] - 0s - loss: 3.8404e-06 - acc: 1.0000
# Epoch 4/100
# 1000/1000 [==============================] - 0s - loss: 3.5237e-06 - acc: 1.0000
# Epoch 5/100
# 1000/1000 [==============================] - 0s - loss: 3.2000e-06 - acc: 1.0000
# Epoch 6/100
# 1000/1000 [==============================] - 0s - loss: 2.9919e-06 - acc: 1.0000
# Epoch 7/100
# 1000/1000 [==============================] - 0s - loss: 2.6128e-06 - acc: 1.0000
# Epoch 8/100
# 1000/1000 [==============================] - 0s - loss: 3.8016e-06 - acc: 1.0000
# Epoch 9/100
# 1000/1000 [==============================] - ETA: 0s - loss: 2.8079e-07 - acc: 1.000 - 0s - loss: 3.1888e-06 - acc: 1.0000
# Epoch 10/100
# ...

# %%
model.get_weights()
# Out:
# [array([[ -6.38144910e-02,   2.58254200e-01,  -1.51913941e-01,
#           -1.51729479e-01,   4.89264727e-03,  -1.67587608e-01,
#           -3.41266543e-01,   3.06550473e-01,   5.16582429e-02,
#            1.12305433e-01,  -3.17037940e-01,  -1.67277798e-01,
#            7.80832171e-02,   3.04113328e-02,  -3.43624353e-01,
#            2.56426036e-02,   2.31414884e-01,  -2.71954030e-01,
#           -2.16676354e-01,  -1.25861794e-01,   2.26962775e-01,
#            3.89601290e-02,  -7.28233457e-02,  -1.42691791e-01,
#            1.82828337e-01,  -1.16011530e-01,  -3.54132712e-01,
#            1.31524891e-01,   1.13864481e-01,   1.51682198e-02,
#           -3.22530001e-01,  -1.37862056e-01],
#         [ -1.86533749e-01,  -1.84435010e-01,   1.49642557e-01,
#           -3.67858708e-02,   2.05169886e-01,   3.29120547e-01,
#            5.08484840e-02,   2.84715742e-01,   1.46397263e-01,
#           -1.51766613e-01,  -7.23948777e-02,  -1.49142310e-01,
# ...

# %%
No, Yes = model.evaluate(np.array([list(map(float, "{:010b}".format(1022)))]),
                         np.array([list(map(float, "{:010b}".format(1023)))]), batch_size=128)
if Yes > No:
    print('Yes')
else:
    print('NO')
No, Yes
2 ** 10
# Out:
# 1/1 [==============================] - 0s
# Yes
# 1024
