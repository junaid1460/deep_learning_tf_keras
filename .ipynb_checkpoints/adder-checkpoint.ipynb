# %%
import numpy as np
import random

def makeBin(a):
    x = "{:010b}".format(a)
    x = list(map(lambda x:x == '1', x))
    return x

def genData(a, b, evalu = False, mistake = False):
    c = a + b
    if mistake:
        c += random.randint(10,100)
    if evalu:
        print("{} + {} = {}".format(a, b, c))
    ret = [a, b, c]
    ret = list(map(makeBin, ret))
    a, b, c = ret
    return (a + b, c)

# %%
data_x = []
data_y = []
count = 100
for i in range(count):
    a = random.randint(0, 100)
    b = random.randint(0, 100)
    x, y = genData(a, b)
    data_x.append(x)
    data_y.append(y)

# %%
data_x, data_y
# Out:
# ([[False,
#    False,
#    False,
#    True,
#    False,
#    True,
#    True,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    True,
#    True,
#    False],
#   [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True],
#   [False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    True,
#    False,
#    False],
#   [False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    True,
#    True,
#    True,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    False,
#    True],
#   [False,
#    False,
#    False,
#    False,
#    False,
# ...

# %%
from keras.layers.core import Dense, Activation
from keras.models import Sequential

# %%
model = Sequential()
model.add(Dense(100, input_shape = (20,), activation="relu"))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation = 'sigmoid'))
model.add(Dense(10, activation='relu'))

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics = ['accuracy'] )

# %%
data_x = []
data_y = []
count = 100
for i in range(count):
    a = random.randint(0, 100)
    b = random.randint(0, 100)
    x, y = genData(a, b)
    data_x.append(x)
    data_y.append(y)

model.fit(x = data_x, y = data_y, batch_size = 10, epochs = 500)
# Out:
# Epoch 1/500
# 100/100 [==============================] - 0s - loss: 2.7898 - acc: 0.7340
# Epoch 2/500
# 100/100 [==============================] - 0s - loss: 2.4256 - acc: 0.7630
# Epoch 3/500
# 100/100 [==============================] - 0s - loss: 2.2624 - acc: 0.7660
# Epoch 4/500
# 100/100 [==============================] - 0s - loss: 2.1227 - acc: 0.7810
# Epoch 5/500
# 100/100 [==============================] - 0s - loss: 1.9851 - acc: 0.7950
# Epoch 6/500
# 100/100 [==============================] - 0s - loss: 1.8577 - acc: 0.7980
# Epoch 7/500
# 100/100 [==============================] - 0s - loss: 1.7497 - acc: 0.8080
# Epoch 8/500
# 100/100 [==============================] - 0s - loss: 1.6760 - acc: 0.8170
# Epoch 9/500
# 100/100 [==============================] - 0s - loss: 1.6029 - acc: 0.8250
# Epoch 10/500
# 100/100 [==============================] - 0s - loss: 1.5291 - acc: 0.8300
# Epoch 11/500
# ...

# %%
data_x_eval = []
data_y_eval = []
count = 1
for i in range(count):
    a = random.randint(0, 100)
    b = random.randint(0, 100)
    x, y = genData(a, b, True)
    data_x_eval.append(x)
    data_y_eval.append(y)
    
data_x_eval = np.array(data_x_eval)
data_y_eval = np.array(data_y_eval)


model.evaluate(data_x_eval, data_y_eval)
# Out:
# 48 + 91 = 139
# 1/1 [==============================] - 0s
# [1.199148416519165, 0.80000001192092896]

# %%
data_x_eval = []
data_y_eval = []
count = 1
for i in range(count):
    a = random.randint(0, 100)
    b = random.randint(0, 100)
    x, y = genData(a, b, True, True)
    data_x_eval.append(x)
    data_y_eval.append(y)
    
data_x_eval = np.array(data_x_eval)
data_y_eval = np.array(data_y_eval)


model.evaluate(data_x_eval, data_y_eval)
# Out:
# 30 + 35 = 91
# 1/1 [==============================] - 0s
# [2.671959400177002, 0.80000001192092896]
