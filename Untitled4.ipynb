# %%
import random
import cv2
import PIL.Image as image
import matplotlib.pyplot as plt

# %%
img = image.open('dd.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x1280 at 0x7F86C6ECCBE0>

# %%
def noise(x):
    return x * 0.6

img.point(lambda x: noise(x))
# Out:
# <PIL.Image.Image image mode=RGB size=960x1280 at 0x7F86F3D38240>

# %%
plt.plot(img.histogram())
plt.show()

# %%
img.
