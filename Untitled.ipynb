# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import imageio as imio
import PIL.Image as image
import numpy as np
import skvideo

# %%
vid = imio.get_reader('./input.mp4', 'ffmpeg')

# %%
vid.request.mode
# Out:
# 'r?'

# %%
pic = image.open('./dd.jpg')
plt.imread('./dd.jpg')
# Out:
# array([[[242, 241, 246],
#         [239, 243, 246],
#         [239, 243, 246],
#         ...,
#         [117, 115, 116],
#         [121, 121, 121],
#         [122, 122, 124]],
#
#        [[239, 243, 246],
#         [239, 243, 246],
#         [239, 242, 247],
#         ...,
#         [121, 121, 121],
#         [122, 122, 122],
#         [121, 121, 121]],
#
#        [[239, 243, 246],
#         [239, 243, 246],
#         [241, 242, 247],
#         ...,
#         [123, 125, 124],
#         [125, 125, 125],
#         [122, 122, 122]],
#
#        ...,
#        [[175, 139, 153],
#         [173, 137, 151],
#         [175, 139, 151],
#         ...,
#         [ 96,  69, 120],
#         [ 96,  69, 122],
#         [ 91,  67, 119]],
#
#        [[173, 137, 151],
#         [174, 136, 151],
#         [170, 134, 146],
#         ...,
#         [ 93,  66, 117],
#         [ 92,  65, 118],
#         [ 93,  69, 121]],
#
#        [[173, 137, 151],
#         [170, 134, 148],
#         [169, 133, 147],
# ...

# %%
count = 0
while count < 2:
    plt.imshow(np.array(vid.get_next_data()))
    plt.show()
    for i in range(15):
        vid.get_next_data()
    count += 1

# %%
import skvideo.io as vio
import skvideo.datasets as vdata
import skvideo.utils as vut

# %%
vf = vio.vread(vdata.bigbuckbunny())

# %%
count = 0
for i in vf:
    plt.imshow(i)
    plt.show()
    if count >= 10:
        break;
    count += 1
